# %% [markdown]
# <a href="https://colab.research.google.com/github/BakMarino/controle-financeiro/blob/main/Script_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1º Seção

# %%
! pip install panda
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from panda) (75.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from panda) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->panda) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->panda) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->panda) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->panda) (2024.12.14)
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py) ... done
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=da111c0138eb4e6e6747ccd9dc0aad1dbac12d8a56d1ce9ee0cb6d3793d3e8f1
#   Stored in directory: /root/.cache/pip/wheels/df/5c/39/36f8dae25a1e88d6ec4411dec4a143781e64fdff6897758eec
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(7)
#vetor com numeros inteiros aleatorios entre 1, 1500, com 10 amostras.

y = np.random.randint(low =1, high = 1500, size = 10)

# %%
y
# Out:
# array([ 176, 1221,  538,  503,  212,  920, 1373, 1210, 1423,  536])

# %%
plt.plot(y)

# %%
# insere a primeira linha do plot
plt.plot(y,color = '#749187', marker = 'o', ms = 5, mec = 'k',
         markerfacecolor = 'w', ls = '-.')

#insere a segunda linha no plot
plt.plot(y*2, marker = '+', color = 'k', ms = 5)

#rotulos
plt.xlabel('Eixo X', color = 'red', size = 12, loc = 'center')
plt.ylabel('Eixo Y')
plt.title('Meu primeiro gráfico', loc = 'left')

#gridlines
plt.grid(axis = 'y', color = 'gray',
         linestyle = '--', linewidth = 1,
         alpha = 0.8)
plt.show()

# %%
np.random.seed(6)
x = np.arange(1, 11)
y1 = np.random.randint(1, 400, 10)
y2 = np.random.randint(150, 500, 10)
y3 = np.random.randint(200, 600, 10)

plt.figure(figsize = (15, 5))
plt.suptitle('Figura', fontsize = 15)

plt.subplot(1, 3, 1)
plt.plot(x, y1, color = 'blue')
plt.title('Grafico 1', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1, 3, 2)
plt.plot(x, y2, color = 'red')
plt.title('Grafico 2', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1, 3, 3)
plt.plot(x, y3, color = 'green')
plt.title('Grafico 3', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.tight_layout(pad = 4)
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize = (15, 4))
fig.suptitle('Figure')
ax[0].plot(x, y1, color = 'blue')
ax[1].plot(x, y2, color = 'red')
ax[2].plot(x, y3, color = 'green')

for i in range(3):
  ax[i].set(title = f'Subplot {i+1}', xlabel = 'Eixo X', ylabel = 'Eixo Y')

# %%
data = np.random.normal(10, 0.5, 5000)
plt.hist(data)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Grafico de Bloco')
plt.show()

# %%
plt.boxplot(data);
plt.hist(data)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Grafico de Bloco')
plt.show()

# %%
x = np.random.normal(10, 0.5, 100)
y = np.random.uniform(0, 20, 100)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y, marker = 'o', color = 'blue', label = 'data 1', alpha= 0.5)
ax.scatter(x*0.5, y*0.5, marker = 'v', color = 'black', label = 'data 2', alpha = 0.7)
ax.legend()

# %%
import plotly.express as px

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
df = px.data.gapminder().query('country == "Brazil"').set_index('year')

# %%
df.head()
# Out:
#      country continent  lifeExp        pop    gdpPercap iso_alpha  iso_num
# year
# 1952  Brazil  Americas   50.917   56602560  2108.944355       BRA       76
# 1957  Brazil  Americas   53.285   65551171  2487.365989       BRA       76
# 1962  Brazil  Americas   55.665   76039390  3336.585802       BRA       76
# 1967  Brazil  Americas   57.632   88049823  3429.864357       BRA       76
# 1972  Brazil  Americas   59.504  100840058  4985.711467       BRA       76

# %%
plt.plot(df.index, df['gdpPercap'])
plt.title('PIB Per Capita do Brasil')
plt.ylabel('PIB Per Capita')
plt.xlabel('Tempo');

# %%
plt.plot(df.index, df['lifeExp'])
plt.title('Expectativa de vida do Brasil')
plt.ylabel('Expectativa de vida')
plt.xlabel('Tempo');

# %%
title = 'Relação entre a expectativa de vida e renda per capita no Brasil'

plt.figure(figsize= (12, 4))
plt.scatter(df['lifeExp'], df['gdpPercap'], cmap ='viridis')
plt.xlabel('Expectativa de Vida')
plt.ylabel('Renda per capita')
plt.title(title, loc = 'left')
plt.show()
# Out:
# <ipython-input-45-8c0b4d27c6bb>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(df['lifeExp'], df['gdpPercap'], cmap ='viridis')

# %%
plt.bar(x = df.index,
        height =df['pop'],
        color = 'blue'
        )
plt.title('População do Brasileira')
plt.ylabel('População')
# Out:
# Text(0, 0.5, 'População')

# %%
def filtrar_continente(continente):
  df = px.data.gapminder()
  df = df[df['continent'] == continente]
  return df

# %%
def filtrar_pais(pais, variavel):
  'Filtrar algum pais da amostra para as variaveis "pop", "gdpPercap", "lifeExp"'
  df = px.data.gapminder()
  df = df[df['country'] == pais][variavel]
  return df

# %%
americas = filtrar_continente('Americas')
paises = americas['country'].unique()
plt.figure(figsize = (12, 8))
for pais in paises:
  plt.scatter(filtrar_pais(pais = pais,
                           variavel = 'lifeExp'
                           ),
              filtrar_pais(pais = pais,
                           variavel = 'gdpPercap'
                           ))
plt.legend(labels = paises, loc = 'best' )
plt.title('Relação entre Expectativa de vida e PIB')
plt.xlabel('Expectativa de vida')
plt.ylabel('PIB per capita');
